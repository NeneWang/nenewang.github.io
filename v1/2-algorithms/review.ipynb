# %% [markdown]
# ```py
# def findmaxsub(arr, l, r)
#     m = (arr//2 )+ 1
#     lh, ll, lsum = findmaxsub(arr, l, m-1)
#     rh, rl, rsum = findmaxsub(arr, m+1, r)
#     ch, cl, csum = ...
#
#     return max(...)
#
# def findmaxsubcross(arr, l, r):
#     maxSumL = -inf
#     Lr = l
#     m = arrsize//2
#     for i in l...m:
#         if ...
#
#     maxSumR = -inf
#     Hr = r
#     for i in m...r:
#         if ...
#
#     return (lr, hr, lsum + rsum)
#
# ```

# %% [markdown]
# ```py
#
# def matrixchain(dim):
#     minmult ... 0
#
#     for chainlen in 2...len(dim) + 1:
#         for start in 0...len(mat) - len(chainlen) + 1:
#             for end in start+chainlen ... len(dim)-2:
#                 minmult[start][end] = -inf
#                 for split in range(start, end):
#                     cost = (
#                         minmult[start], [split] +
#                         minmult[split + 1][end]+
#                         mat[start] * mat[split + 1] + mat[end + 1]
#                     )
#                     if cost < minmult[start][end]:
#                         minmult[start][end] = cost
#                         split[start][end] = split
#
#     return min_mult, split_points
#
#     def print_optimal_parent(start, end, splits):
#         if start == end:
#             print(fmat[start][end])
#         else:
#             print"("
#             plit = splits[start][end]
#             print_opt_parent(start, split, splits)
#             print_opt_parent(split + 1, end, splits)
#             print )
#
#
#
# ```
#
#
# 1. transplant if parent is none.
# 2. if oldnode same, than left, then parent.left = node
# ```py
# def transplant(tree, old_node, new_node):
#     # If the parent is none, then
#     if old_node.parent is None:
#         tree.root = new_node
#     elif old_node == old_node.parent.left:
#         old_node.parent.left = new_node
#     else:
#         # otherwise the right should be
#         old_node.parent.right = new_node
#
#
#     # Set the parent as the old node parent
#     if new_node is not None:
#         mew_node.parent = old_node.parent
#
# def tree_delete(tree, node_to_delete):
#     if is single child. change single child
#     other wise find successor:
#     if sucessor is not direct child of node
#         transplant right and swap with position successor
#         suuccess.right = node.right
#         node.right.parent = successor
#     transplant successor and the node to delete
#     successor.left = node_to_delete.left
#     node to delete.left.parent = successor
#
# def transplant(node, node to replace):
#     checks if is left child of parent, then
#         nodet.parent.left = rplace
#     else if node.parent.right = node
#         node.parent.right = repplace
#     else:
#         if is nodne then
#             t.root = replace
#
#  de ftransplatn:
#     if node.parent is nil;
#         t.root = replace
#     if node.parent.left = node
#         node.parent.left = replace
#     else:
#         node.parent.right = replace
#
# def delete:
#     if less is none. replace
#         transplant9nodnde, node.right)
#     elif node.right is None:
#         transplant(node, node.left)
#     else:
#         find succ = min (node.right)
#
#         if not succ == node.right:
#             tranplant(succ, succ.right)
#             succ.right.parent = succ
#         transplant(succ, succ, left)
#         succ.left.parent = succ
#
#
# def tranplant(node, newnode, T):
#     if no parent do nothing.
#     if parent left is node:
#         node.parent.left = newnode
#     elif
#         node...rigt = new
#
# def deleteTree
#     if singlechild:
#             the other
#     else:
#         succ
#         if succ = =!= aprent.right
#             tranplant succ and succ.right
#             succ.right = node.right
#             succ.right.parent = succ
#         # parents
#         transplant node and succ
#         succ.left = node.left
#         succ.left.parent = succ
#
#
# def delete tree
# transplant(succ, succ.right)
# succ.right = node.right
#
#
#
# def de
# transplant(succ, succ.right)
# nsuc.right = parent.right
# succ.r.p = succ
#
# ```
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I mean with those salaries, why not going to `arg`?
# Dang with that salary I should prob consdiering mmoving there. Also better midnset. I am thinking of the following: What if I move there, try my best? earn some real cash, and then try luck in `US` at a higher living rate? Because with that rate I should be able to aford things way better.
#
#
#
#
#
# for i in keys
#     cost ii  = 0
#     cost you clena it, apsps
#
#
#     diag in numkeys
#     ior
